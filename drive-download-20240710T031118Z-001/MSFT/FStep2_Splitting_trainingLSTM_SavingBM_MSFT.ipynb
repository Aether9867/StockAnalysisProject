# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

data = pd.read_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/original/MSFT_dataset.csv")

# %%
# drop nulls
data.isnull().sum()
# select only required columns
UNWANTED_COLS = ["volume"]

# filter columns
df = data[[col for col in list(data.columns) if col not in UNWANTED_COLS]]
df.head()
# Out:
#          date   open   high    low  close
# 0  2013-02-08  27.35  27.71  27.31  27.55
# 1  2013-02-11  27.65  27.92  27.50  27.86
# 2  2013-02-12  27.88  28.00  27.75  27.88
# 3  2013-02-13  27.93  28.11  27.88  28.03
# 4  2013-02-14  27.92  28.06  27.87  28.04

# %%
# conver the data to pandas date time
df["date"] = pd.to_datetime(df["date"])
df.set_index("date", drop = True, inplace = True)
df.head()
# Out:
# <ipython-input-4-76cabfe32200>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date"] = pd.to_datetime(df["date"])
#              open   high    low  close
# date
# 2013-02-08  27.35  27.71  27.31  27.55
# 2013-02-11  27.65  27.92  27.50  27.86
# 2013-02-12  27.88  28.00  27.75  27.88
# 2013-02-13  27.93  28.11  27.88  28.03
# 2013-02-14  27.92  28.06  27.87  28.04

# %%
df.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/MSFT_after_date_conversion.csv",index=False)

# %% [markdown]
# Time series plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
COMPANY = "MSFT"
plt.figure(figsize = (12,6))
plt.plot(df["open"])
plt.xlabel("Time")
plt.ylabel("Open Stock Prices")
plt.title("Open Price of {} Stock Over time".format(COMPANY))
plt.grid(True)
plt.show()

# %% [markdown]
# Preprocessing Using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
import pickle
import os

MODEL_SAVE_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

COLUMNS = list(df.columns)
print("Columns", COLUMNS)

# fit the model
scaler = MinMaxScaler().fit(df[COLUMNS])
# save the model
with open(os.path.join(MODEL_SAVE_PATH, f"{COMPANY}scalermodel"), "wb") as tesla_model:
    pickle.dump(scaler, tesla_model)
    print("Model Saved")

# fot on data
df[COLUMNS] = scaler.transform(df[COLUMNS])
# Out:
# Columns ['open', 'high', 'low', 'close']
# Model Saved
# <ipython-input-7-3f0d68f0936a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[COLUMNS] = scaler.transform(df[COLUMNS])

# %%
df[COLUMNS]
# Out:
#                 open      high       low     close
# date
# 2013-02-08  0.000000  0.001607  0.001203  0.002661
# 2013-02-11  0.004425  0.004674  0.004061  0.007244
# 2013-02-12  0.007818  0.005842  0.007821  0.007540
# 2013-02-13  0.008556  0.007449  0.009776  0.009758
# 2013-02-14  0.008408  0.006718  0.009626  0.009905
# ...              ...       ...       ...       ...
# 2018-02-01  0.994837  1.000000  0.997914  0.988912
# 2018-02-02  0.977873  0.969330  0.966612  0.952247
# 2018-02-05  0.932438  0.958668  0.913972  0.896363
# 2018-02-06  0.878301  0.932890  0.872612  0.945594
# 2018-02-07  0.931406  0.937199  0.932020  0.920166
#
# [1259 rows x 4 columns]

# %% [markdown]
# Splitting dataset

# %%
# define the plsit ratio
SPLIT_RATIO = 0.2

# train length
train_length = int(len(df) * (1 - SPLIT_RATIO))
print("train length", train_length)

train_data = df[:train_length]
test_data = df[train_length:]
print("train shape", train_data.shape)
print("test shape", test_data.shape)
# Out:
# train length 1007
# train shape (1007, 4)
# test shape (252, 4)

# %%
test_data.dtypes
# Out:
# open     float64
# high     float64
# low      float64
# close    float64
# dtype: object

# %% [markdown]
# Saving scaled data to csv

# %%
train_data.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/MSFT_train_scaled.csv",index=False)
test_data.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/MSFT_test_scaled.csv",index=False)

# %%
import numpy as np

def prepare_seq(data,seq_len):    #eg seq=len = 50
    sequences,labels = [],[]
    #len of data is 1353 then 1353 - 50 is the range
    for i in range(len(data) - seq_len):
        #eg 0 to 50
        x_temp = data.iloc[i:i+seq_len].values
        #stores 50th value
        y_temp = data.iloc[i+seq_len].values

        sequences.append(x_temp)
        labels.append(y_temp)

    return np.array(sequences), np.array(labels)

# %%
# define the sequence length
SEQ_LENGTH = 50

# process the dataset
train_sequences,train_labels = prepare_seq(train_data, SEQ_LENGTH)
test_sequences,test_labels = prepare_seq(test_data, SEQ_LENGTH)
print(train_sequences.shape, test_sequences.shape)
# Out:
# (957, 50, 4) (202, 50, 4)

# %% [markdown]
# LSTM model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout
from tensorflow.keras.optimizers import Adam

# define the learning rate and epochs
LR = 0.001
EPOCHS = 50

# build the model
model = Sequential()
model.add(LSTM(units=50,return_sequences = True, input_shape=(train_sequences.shape[1],train_sequences.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(units = 50))
model.add(Dense(4))

# compile the model
model.compile(optimizer=Adam(learning_rate = LR), loss='mean_squared_error', metrics=['mean_squared_error'])

# %% [markdown]
# LSTM training

# %%
# train the model
model.fit(train_sequences,train_labels, epochs=EPOCHS, validation_data = (test_sequences,test_labels),verbose = 'auto')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 7s 88ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 2/50
# 30/30 [==============================] - 2s 57ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 3/50
# 30/30 [==============================] - 3s 85ms/step - loss: 6.1567e-04 - mean_squared_error: 6.1567e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 4/50
# 30/30 [==============================] - 2s 81ms/step - loss: 5.6643e-04 - mean_squared_error: 5.6643e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 5/50
# 30/30 [==============================] - 1s 48ms/step - loss: 5.4616e-04 - mean_squared_error: 5.4616e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 6/50
# 30/30 [==============================] - 1s 50ms/step - loss: 5.2244e-04 - mean_squared_error: 5.2244e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 7/50
# 30/30 [==============================] - 2s 53ms/step - loss: 5.0763e-04 - mean_squared_error: 5.0763e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 8/50
# 30/30 [==============================] - 2s 50ms/step - loss: 5.2466e-04 - mean_squared_error: 5.2466e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 9/50
# 30/30 [==============================] - 1s 50ms/step - loss: 4.8447e-04 - mean_squared_error: 4.8447e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 10/50
# 30/30 [==============================] - 2s 51ms/step - loss: 4.6440e-04 - mean_squared_error: 4.6440e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 11/50
# 30/30 [==============================] - 2s 68ms/step - loss: 4.6607e-04 - mean_squared_error: 4.6607e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 12/50
# 30/30 [==============================] - 3s 84ms/step - loss: 4.5416e-04 - mean_squared_error: 4.5416e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 13/50
# 30/30 [==============================] - 2s 70ms/step - loss: 4.4309e-04 - mean_squared_error: 4.4309e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 14/50
# 30/30 [==============================] - 2s 51ms/step - loss: 4.3205e-04 - mean_squared_error: 4.3205e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 15/50
# 30/30 [==============================] - 1s 49ms/step - loss: 4.8716e-04 - mean_squared_error: 4.8716e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
# Epoch 16/50
# 30/30 [==============================] - 1s 48ms/step - loss: 4.8552e-04 - mean_squared_error: 4.8552e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 17/50
# 30/30 [==============================] - 1s 48ms/step - loss: 4.2457e-04 - mean_squared_error: 4.2457e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 18/50
# 30/30 [==============================] - 1s 47ms/step - loss: 4.2270e-04 - mean_squared_error: 4.2270e-04 - val_loss: 7.1391e-04 - val_mean_squared_error: 7.1391e-04
# Epoch 19/50
# 30/30 [==============================] - 1s 49ms/step - loss: 4.2946e-04 - mean_squared_error: 4.2946e-04 - val_loss: 6.6364e-04 - val_mean_squared_error: 6.6364e-04
# Epoch 20/50
# 30/30 [==============================] - 2s 70ms/step - loss: 4.2321e-04 - mean_squared_error: 4.2321e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 21/50
# 30/30 [==============================] - 2s 82ms/step - loss: 3.8436e-04 - mean_squared_error: 3.8436e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 22/50
# 30/30 [==============================] - 2s 65ms/step - loss: 3.8161e-04 - mean_squared_error: 3.8161e-04 - val_loss: 6.7385e-04 - val_mean_squared_error: 6.7385e-04
# Epoch 23/50
# 30/30 [==============================] - 1s 47ms/step - loss: 3.8006e-04 - mean_squared_error: 3.8006e-04 - val_loss: 5.7679e-04 - val_mean_squared_error: 5.7679e-04
# Epoch 24/50
# 30/30 [==============================] - 1s 48ms/step - loss: 3.8245e-04 - mean_squared_error: 3.8245e-04 - val_loss: 9.6158e-04 - val_mean_squared_error: 9.6158e-04
# Epoch 25/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.9324e-04 - mean_squared_error: 3.9324e-04 - val_loss: 5.6959e-04 - val_mean_squared_error: 5.6959e-04
# Epoch 26/50
# 30/30 [==============================] - 1s 48ms/step - loss: 3.7931e-04 - mean_squared_error: 3.7931e-04 - val_loss: 6.2386e-04 - val_mean_squared_error: 6.2386e-04
# Epoch 27/50
# 30/30 [==============================] - 1s 47ms/step - loss: 3.6259e-04 - mean_squared_error: 3.6259e-04 - val_loss: 8.4421e-04 - val_mean_squared_error: 8.4421e-04
# Epoch 28/50
# 30/30 [==============================] - 2s 52ms/step - loss: 3.4411e-04 - mean_squared_error: 3.4411e-04 - val_loss: 4.5090e-04 - val_mean_squared_error: 4.5090e-04
# Epoch 29/50
# 30/30 [==============================] - 2s 80ms/step - loss: 3.3706e-04 - mean_squared_error: 3.3706e-04 - val_loss: 4.7826e-04 - val_mean_squared_error: 4.7826e-04
# Epoch 30/50
# 30/30 [==============================] - 3s 86ms/step - loss: 3.8064e-04 - mean_squared_error: 3.8064e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 31/50
# 30/30 [==============================] - 2s 58ms/step - loss: 3.9668e-04 - mean_squared_error: 3.9668e-04 - val_loss: 7.4840e-04 - val_mean_squared_error: 7.4840e-04
# Epoch 32/50
# 30/30 [==============================] - 2s 51ms/step - loss: 3.6140e-04 - mean_squared_error: 3.6140e-04 - val_loss: 5.1962e-04 - val_mean_squared_error: 5.1962e-04
# Epoch 33/50
# 30/30 [==============================] - 2s 53ms/step - loss: 3.7003e-04 - mean_squared_error: 3.7003e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 34/50
# 30/30 [==============================] - 1s 50ms/step - loss: 3.3505e-04 - mean_squared_error: 3.3505e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 35/50
# 30/30 [==============================] - 1s 47ms/step - loss: 3.5536e-04 - mean_squared_error: 3.5536e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 36/50
# 30/30 [==============================] - 2s 51ms/step - loss: 3.2841e-04 - mean_squared_error: 3.2841e-04 - val_loss: 4.3480e-04 - val_mean_squared_error: 4.3480e-04
# Epoch 37/50
# 30/30 [==============================] - 2s 59ms/step - loss: 3.3358e-04 - mean_squared_error: 3.3358e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 38/50
# 30/30 [==============================] - 2s 79ms/step - loss: 3.0553e-04 - mean_squared_error: 3.0553e-04 - val_loss: 6.6833e-04 - val_mean_squared_error: 6.6833e-04
# Epoch 39/50
# 30/30 [==============================] - 2s 79ms/step - loss: 3.1598e-04 - mean_squared_error: 3.1598e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 40/50
# 30/30 [==============================] - 1s 50ms/step - loss: 3.3270e-04 - mean_squared_error: 3.3270e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 41/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.2348e-04 - mean_squared_error: 3.2348e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 42/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.5318e-04 - mean_squared_error: 3.5318e-04 - val_loss: 7.0483e-04 - val_mean_squared_error: 7.0483e-04
# Epoch 43/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.2322e-04 - mean_squared_error: 3.2322e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 44/50
# 30/30 [==============================] - 1s 49ms/step - loss: 3.1353e-04 - mean_squared_error: 3.1353e-04 - val_loss: 8.9038e-04 - val_mean_squared_error: 8.9038e-04
# Epoch 45/50
# 30/30 [==============================] - 2s 84ms/step - loss: 2.8737e-04 - mean_squared_error: 2.8737e-04 - val_loss: 8.2293e-04 - val_mean_squared_error: 8.2293e-04
# Epoch 46/50
# 30/30 [==============================] - 3s 102ms/step - loss: 2.9859e-04 - mean_squared_error: 2.9859e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 47/50
# 30/30 [==============================] - 2s 81ms/step - loss: 3.0292e-04 - mean_squared_error: 3.0292e-04 - val_loss: 7.1361e-04 - val_mean_squared_error: 7.1361e-04
# Epoch 48/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.8153e-04 - mean_squared_error: 2.8153e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 49/50
# 30/30 [==============================] - 2s 51ms/step - loss: 2.6708e-04 - mean_squared_error: 2.6708e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 50/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.8955e-04 - mean_squared_error: 2.8955e-04 - val_loss: 4.0693e-04 - val_mean_squared_error: 4.0693e-04

# %% [markdown]
# Saving best model LSTM

# %%
SAVE = True
LSTM_MODEL_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

# save the model if needed
if SAVE:
    model.save(os.path.join(LSTM_MODEL_PATH, f"best_model_{COMPANY}_LSTM.h5"))
    print("Model is saved")
# Out:
# Model is saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# GRU model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,GRU,Dropout
from tensorflow.keras.optimizers import Adam

# define the learning rate and epochs
LR = 0.001
EPOCHS = 50

# build the model
model_GRU = Sequential()
model_GRU.add(GRU(units=50,return_sequences = True, input_shape=(train_sequences.shape[1],train_sequences.shape[2])))
model_GRU.add(Dropout(0.1))
model_GRU.add(GRU(units = 50))
model_GRU.add(Dense(4))

# compile the model
model_GRU.compile(optimizer=Adam(learning_rate = LR), loss='mean_squared_error', metrics=['mean_squared_error'])

# %% [markdown]
# Training GRU

# %%
# train the model
model_GRU.fit(train_sequences,train_labels, epochs=EPOCHS, validation_data = (test_sequences,test_labels),verbose = 'auto')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 10s 153ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# Epoch 2/50
# 30/30 [==============================] - 3s 93ms/step - loss: 9.0651e-04 - mean_squared_error: 9.0651e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 3/50
# 30/30 [==============================] - 2s 57ms/step - loss: 4.6018e-04 - mean_squared_error: 4.6018e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 4/50
# 30/30 [==============================] - 2s 52ms/step - loss: 4.0219e-04 - mean_squared_error: 4.0219e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 5/50
# 30/30 [==============================] - 2s 50ms/step - loss: 3.9363e-04 - mean_squared_error: 3.9363e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 6/50
# 30/30 [==============================] - 2s 52ms/step - loss: 3.9783e-04 - mean_squared_error: 3.9783e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 7/50
# 30/30 [==============================] - 2s 50ms/step - loss: 3.8528e-04 - mean_squared_error: 3.8528e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 8/50
# 30/30 [==============================] - 2s 51ms/step - loss: 3.4053e-04 - mean_squared_error: 3.4053e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 9/50
# 30/30 [==============================] - 2s 60ms/step - loss: 3.3827e-04 - mean_squared_error: 3.3827e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 10/50
# 30/30 [==============================] - 2s 81ms/step - loss: 3.2850e-04 - mean_squared_error: 3.2850e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 11/50
# 30/30 [==============================] - 2s 80ms/step - loss: 3.4607e-04 - mean_squared_error: 3.4607e-04 - val_loss: 9.3511e-04 - val_mean_squared_error: 9.3511e-04
# Epoch 12/50
# 30/30 [==============================] - 2s 52ms/step - loss: 3.5199e-04 - mean_squared_error: 3.5199e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 13/50
# 30/30 [==============================] - 1s 49ms/step - loss: 2.9867e-04 - mean_squared_error: 2.9867e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 14/50
# 30/30 [==============================] - 2s 54ms/step - loss: 3.0173e-04 - mean_squared_error: 3.0173e-04 - val_loss: 9.0571e-04 - val_mean_squared_error: 9.0571e-04
# Epoch 15/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.9942e-04 - mean_squared_error: 2.9942e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 16/50
# 30/30 [==============================] - 2s 53ms/step - loss: 2.8121e-04 - mean_squared_error: 2.8121e-04 - val_loss: 6.2779e-04 - val_mean_squared_error: 6.2779e-04
# Epoch 17/50
# 30/30 [==============================] - 2s 51ms/step - loss: 2.6778e-04 - mean_squared_error: 2.6778e-04 - val_loss: 9.5246e-04 - val_mean_squared_error: 9.5246e-04
# Epoch 18/50
# 30/30 [==============================] - 2s 73ms/step - loss: 2.9065e-04 - mean_squared_error: 2.9065e-04 - val_loss: 8.5478e-04 - val_mean_squared_error: 8.5478e-04
# Epoch 19/50
# 30/30 [==============================] - 3s 87ms/step - loss: 2.8604e-04 - mean_squared_error: 2.8604e-04 - val_loss: 8.4280e-04 - val_mean_squared_error: 8.4280e-04
# Epoch 20/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.5443e-04 - mean_squared_error: 2.5443e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 21/50
# 30/30 [==============================] - 2s 51ms/step - loss: 2.6953e-04 - mean_squared_error: 2.6953e-04 - val_loss: 9.7295e-04 - val_mean_squared_error: 9.7295e-04
# Epoch 22/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.6089e-04 - mean_squared_error: 2.6089e-04 - val_loss: 5.0808e-04 - val_mean_squared_error: 5.0808e-04
# Epoch 23/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.4990e-04 - mean_squared_error: 2.4990e-04 - val_loss: 6.5179e-04 - val_mean_squared_error: 6.5179e-04
# Epoch 24/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.5384e-04 - mean_squared_error: 2.5384e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 25/50
# 30/30 [==============================] - 2s 51ms/step - loss: 2.3786e-04 - mean_squared_error: 2.3786e-04 - val_loss: 8.8261e-04 - val_mean_squared_error: 8.8261e-04
# Epoch 26/50
# 30/30 [==============================] - 2s 62ms/step - loss: 2.4719e-04 - mean_squared_error: 2.4719e-04 - val_loss: 5.6975e-04 - val_mean_squared_error: 5.6975e-04
# Epoch 27/50
# 30/30 [==============================] - 2s 82ms/step - loss: 2.3871e-04 - mean_squared_error: 2.3871e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 28/50
# 30/30 [==============================] - 2s 78ms/step - loss: 2.3095e-04 - mean_squared_error: 2.3095e-04 - val_loss: 9.7137e-04 - val_mean_squared_error: 9.7137e-04
# Epoch 29/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.4609e-04 - mean_squared_error: 2.4609e-04 - val_loss: 4.8147e-04 - val_mean_squared_error: 4.8147e-04
# Epoch 30/50
# 30/30 [==============================] - 1s 50ms/step - loss: 2.5352e-04 - mean_squared_error: 2.5352e-04 - val_loss: 3.8577e-04 - val_mean_squared_error: 3.8577e-04
# Epoch 31/50
# 30/30 [==============================] - 2s 52ms/step - loss: 2.2430e-04 - mean_squared_error: 2.2430e-04 - val_loss: 9.1244e-04 - val_mean_squared_error: 9.1244e-04
# Epoch 32/50
# 30/30 [==============================] - 2s 51ms/step - loss: 2.0908e-04 - mean_squared_error: 2.0908e-04 - val_loss: 8.4571e-04 - val_mean_squared_error: 8.4571e-04
# Epoch 33/50
# 30/30 [==============================] - 2s 54ms/step - loss: 2.0113e-04 - mean_squared_error: 2.0113e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 34/50
# 30/30 [==============================] - 1s 50ms/step - loss: 1.9644e-04 - mean_squared_error: 1.9644e-04 - val_loss: 4.9533e-04 - val_mean_squared_error: 4.9533e-04
# Epoch 35/50
# 30/30 [==============================] - 2s 71ms/step - loss: 1.9408e-04 - mean_squared_error: 1.9408e-04 - val_loss: 6.4396e-04 - val_mean_squared_error: 6.4396e-04
# Epoch 36/50
# 30/30 [==============================] - 3s 85ms/step - loss: 2.0350e-04 - mean_squared_error: 2.0350e-04 - val_loss: 4.8293e-04 - val_mean_squared_error: 4.8293e-04
# Epoch 37/50
# 30/30 [==============================] - 2s 63ms/step - loss: 2.0656e-04 - mean_squared_error: 2.0656e-04 - val_loss: 3.2739e-04 - val_mean_squared_error: 3.2739e-04
# Epoch 38/50
# 30/30 [==============================] - 1s 50ms/step - loss: 1.9817e-04 - mean_squared_error: 1.9817e-04 - val_loss: 7.4645e-04 - val_mean_squared_error: 7.4645e-04
# Epoch 39/50
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9305e-04 - mean_squared_error: 1.9305e-04 - val_loss: 7.1628e-04 - val_mean_squared_error: 7.1628e-04
# Epoch 40/50
# 30/30 [==============================] - 2s 52ms/step - loss: 1.7975e-04 - mean_squared_error: 1.7975e-04 - val_loss: 6.5289e-04 - val_mean_squared_error: 6.5289e-04
# Epoch 41/50
# 30/30 [==============================] - 2s 51ms/step - loss: 1.9881e-04 - mean_squared_error: 1.9881e-04 - val_loss: 8.5689e-04 - val_mean_squared_error: 8.5689e-04
# Epoch 42/50
# 30/30 [==============================] - 2s 53ms/step - loss: 1.9131e-04 - mean_squared_error: 1.9131e-04 - val_loss: 4.1968e-04 - val_mean_squared_error: 4.1968e-04
# Epoch 43/50
# 30/30 [==============================] - 2s 57ms/step - loss: 1.9208e-04 - mean_squared_error: 1.9208e-04 - val_loss: 2.5386e-04 - val_mean_squared_error: 2.5386e-04
# Epoch 44/50
# 30/30 [==============================] - 2s 83ms/step - loss: 1.8616e-04 - mean_squared_error: 1.8616e-04 - val_loss: 4.5103e-04 - val_mean_squared_error: 4.5103e-04
# Epoch 45/50
# 30/30 [==============================] - 2s 79ms/step - loss: 1.6819e-04 - mean_squared_error: 1.6819e-04 - val_loss: 5.2028e-04 - val_mean_squared_error: 5.2028e-04
# Epoch 46/50
# 30/30 [==============================] - 2s 53ms/step - loss: 1.6696e-04 - mean_squared_error: 1.6696e-04 - val_loss: 2.6095e-04 - val_mean_squared_error: 2.6095e-04
# Epoch 47/50
# 30/30 [==============================] - 2s 53ms/step - loss: 1.7969e-04 - mean_squared_error: 1.7969e-04 - val_loss: 4.4723e-04 - val_mean_squared_error: 4.4723e-04
# Epoch 48/50
# 30/30 [==============================] - 2s 51ms/step - loss: 1.6454e-04 - mean_squared_error: 1.6454e-04 - val_loss: 3.9987e-04 - val_mean_squared_error: 3.9987e-04
# Epoch 49/50
# 30/30 [==============================] - 1s 50ms/step - loss: 1.4648e-04 - mean_squared_error: 1.4648e-04 - val_loss: 6.2475e-04 - val_mean_squared_error: 6.2475e-04
# Epoch 50/50
# 30/30 [==============================] - 2s 53ms/step - loss: 1.5649e-04 - mean_squared_error: 1.5649e-04 - val_loss: 2.5525e-04 - val_mean_squared_error: 2.5525e-04

# %% [markdown]
# Saving best GRU model

# %%
SAVE = True
GRU_MODEL_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

# save the model if needed
if SAVE:
    model_GRU.save(os.path.join(GRU_MODEL_PATH, f"best_model_{COMPANY}_GRU.h5"))
    print("Model is saved")
# Out:
# Model is saved
