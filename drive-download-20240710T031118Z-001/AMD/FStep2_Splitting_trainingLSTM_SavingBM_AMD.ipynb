# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

data = pd.read_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/original/AMD_dataset.csv")

# %%
# drop nulls
data.isnull().sum()
# select only required columns
UNWANTED_COLS = ["volume"]

# filter columns
df = data[[col for col in list(data.columns) if col not in UNWANTED_COLS]]
df.head()
# Out:
#          date   open  high   low  close
# 0  2013-02-08  2.580  2.60  2.58   2.59
# 1  2013-02-11  2.590  2.70  2.59   2.67
# 2  2013-02-12  2.705  2.78  2.69   2.77
# 3  2013-02-13  2.810  2.83  2.73   2.75
# 4  2013-02-14  2.740  2.75  2.69   2.75

# %%
# conver the data to pandas date time
df["date"] = pd.to_datetime(df["date"])
df.set_index("date", drop = True, inplace = True)
df.head()
# Out:
# <ipython-input-7-76cabfe32200>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["date"] = pd.to_datetime(df["date"])
#              open  high   low  close
# date
# 2013-02-08  2.580  2.60  2.58   2.59
# 2013-02-11  2.590  2.70  2.59   2.67
# 2013-02-12  2.705  2.78  2.69   2.77
# 2013-02-13  2.810  2.83  2.73   2.75
# 2013-02-14  2.740  2.75  2.69   2.75

# %%
df.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/AMD_after_date_conversion.csv",index=False)

# %% [markdown]
# Time series plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
COMPANY = "AMD"
plt.figure(figsize = (12,6))
plt.plot(df["open"])
plt.xlabel("Time")
plt.ylabel("Open Stock Prices")
plt.title("Open Price of {} Stock Over time".format(COMPANY))
plt.grid(True)
plt.show()

# %% [markdown]
# Preprocessing Using MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler
import pickle
import os

MODEL_SAVE_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

COLUMNS = list(df.columns)
print("Columns", COLUMNS)

# fit the model
scaler = MinMaxScaler().fit(df[COLUMNS])
# save the model
with open(os.path.join(MODEL_SAVE_PATH, f"{COMPANY}scalermodel"), "wb") as tesla_model:
    pickle.dump(scaler, tesla_model)
    print("Model Saved")

# fot on data
df[COLUMNS] = scaler.transform(df[COLUMNS])
# Out:
# Columns ['open', 'high', 'low', 'close']
# Model Saved
# <ipython-input-10-3f0d68f0936a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[COLUMNS] = scaler.transform(df[COLUMNS])

# %%
df[COLUMNS]
# Out:
#                 open      high       low     close
# date
# 2013-02-08  0.069414  0.065186  0.075136  0.071429
# 2013-02-11  0.070137  0.072350  0.075910  0.077320
# 2013-02-12  0.078453  0.078080  0.083656  0.084683
# 2013-02-13  0.086045  0.081662  0.086754  0.083211
# 2013-02-14  0.080983  0.075931  0.083656  0.083211
# ...              ...       ...       ...       ...
# 2018-02-01  0.867679  0.870344  0.898528  0.856406
# 2018-02-02  0.826464  0.814470  0.838110  0.797496
# 2018-02-05  0.754158  0.751433  0.721921  0.732695
# 2018-02-06  0.681128  0.719914  0.727343  0.738586
# 2018-02-07  0.728850  0.731375  0.768397  0.734904
#
# [1259 rows x 4 columns]

# %% [markdown]
# Splitting dataset

# %%
# define the plsit ratio
SPLIT_RATIO = 0.2

# train length
train_length = int(len(df) * (1 - SPLIT_RATIO))
print("train length", train_length)

train_data = df[:train_length]
test_data = df[train_length:]
print("train shape", train_data.shape)
print("test shape", test_data.shape)
# Out:
# train length 1007
# train shape (1007, 4)
# test shape (252, 4)

# %%
test_data.dtypes
# Out:
# open     float64
# high     float64
# low      float64
# close    float64
# dtype: object

# %% [markdown]
# Saving scaled data to csv

# %%
train_data.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/AMD_train_scaled.csv",index=False)
test_data.to_csv("/content/drive/Shareddrives/1:1_Krishna_Vijay/Dataset/scaledNsplitted/AMD_test_scaled.csv",index=False)

# %%
import numpy as np

def prepare_seq(data,seq_len):    #eg seq=len = 50
    sequences,labels = [],[]
    #len of data is 1353 then 1353 - 50 is the range
    for i in range(len(data) - seq_len):
        #eg 0 to 50
        x_temp = data.iloc[i:i+seq_len].values
        #stores 50th value
        y_temp = data.iloc[i+seq_len].values

        sequences.append(x_temp)
        labels.append(y_temp)

    return np.array(sequences), np.array(labels)

# %%
# define the sequence length
SEQ_LENGTH = 50

# process the dataset
train_sequences,train_labels = prepare_seq(train_data, SEQ_LENGTH)
test_sequences,test_labels = prepare_seq(test_data, SEQ_LENGTH)
print(train_sequences.shape, test_sequences.shape)
# Out:
# (957, 50, 4) (202, 50, 4)

# %% [markdown]
# LSTM model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Dropout
from tensorflow.keras.optimizers import Adam

# define the learning rate and epochs
LR = 0.001
EPOCHS = 50

# build the model
model = Sequential()
model.add(LSTM(units=50,return_sequences = True, input_shape=(train_sequences.shape[1],train_sequences.shape[2])))
model.add(Dropout(0.1))
model.add(LSTM(units = 50))
model.add(Dense(4))

# compile the model
model.compile(optimizer=Adam(learning_rate = LR), loss='mean_squared_error', metrics=['mean_squared_error'])

# %% [markdown]
# LSTM training

# %%
# train the model
model.fit(train_sequences,train_labels, epochs=EPOCHS, validation_data = (test_sequences,test_labels),verbose = 'auto')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 9s 130ms/step - loss: 0.0082 - mean_squared_error: 0.0082 - val_loss: 0.0117 - val_mean_squared_error: 0.0117
# Epoch 2/50
# 30/30 [==============================] - 2s 56ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 3/50
# 30/30 [==============================] - 2s 55ms/step - loss: 9.9147e-04 - mean_squared_error: 9.9147e-04 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 4/50
# 30/30 [==============================] - 2s 56ms/step - loss: 9.5986e-04 - mean_squared_error: 9.5986e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 5/50
# 30/30 [==============================] - 2s 56ms/step - loss: 9.3207e-04 - mean_squared_error: 9.3207e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 6/50
# 30/30 [==============================] - 2s 56ms/step - loss: 8.3825e-04 - mean_squared_error: 8.3825e-04 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 7/50
# 30/30 [==============================] - 3s 93ms/step - loss: 9.0163e-04 - mean_squared_error: 9.0163e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# Epoch 8/50
# 30/30 [==============================] - 3s 109ms/step - loss: 9.3393e-04 - mean_squared_error: 9.3393e-04 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
# Epoch 9/50
# 30/30 [==============================] - 2s 58ms/step - loss: 7.7379e-04 - mean_squared_error: 7.7379e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 10/50
# 30/30 [==============================] - 2s 57ms/step - loss: 9.4065e-04 - mean_squared_error: 9.4065e-04 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 11/50
# 30/30 [==============================] - 2s 56ms/step - loss: 6.8639e-04 - mean_squared_error: 6.8639e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
# Epoch 12/50
# 30/30 [==============================] - 2s 54ms/step - loss: 7.3966e-04 - mean_squared_error: 7.3966e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 13/50
# 30/30 [==============================] - 2s 57ms/step - loss: 7.0465e-04 - mean_squared_error: 7.0465e-04 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
# Epoch 14/50
# 30/30 [==============================] - 2s 56ms/step - loss: 6.8333e-04 - mean_squared_error: 6.8333e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
# Epoch 15/50
# 30/30 [==============================] - 3s 92ms/step - loss: 5.3728e-04 - mean_squared_error: 5.3728e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
# Epoch 16/50
# 30/30 [==============================] - 3s 96ms/step - loss: 5.9195e-04 - mean_squared_error: 5.9195e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 17/50
# 30/30 [==============================] - 4s 121ms/step - loss: 5.6922e-04 - mean_squared_error: 5.6922e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 18/50
# 30/30 [==============================] - 3s 113ms/step - loss: 5.3191e-04 - mean_squared_error: 5.3191e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 19/50
# 30/30 [==============================] - 3s 116ms/step - loss: 4.5096e-04 - mean_squared_error: 4.5096e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 20/50
# 30/30 [==============================] - 5s 161ms/step - loss: 5.0207e-04 - mean_squared_error: 5.0207e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 21/50
# 30/30 [==============================] - 3s 111ms/step - loss: 4.3174e-04 - mean_squared_error: 4.3174e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 22/50
# 30/30 [==============================] - 2s 55ms/step - loss: 4.0985e-04 - mean_squared_error: 4.0985e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 23/50
# 30/30 [==============================] - 2s 56ms/step - loss: 4.3400e-04 - mean_squared_error: 4.3400e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 24/50
# 30/30 [==============================] - 2s 55ms/step - loss: 4.3500e-04 - mean_squared_error: 4.3500e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 25/50
# 30/30 [==============================] - 2s 56ms/step - loss: 4.3039e-04 - mean_squared_error: 4.3039e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 26/50
# 30/30 [==============================] - 2s 60ms/step - loss: 3.7698e-04 - mean_squared_error: 3.7698e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 27/50
# 30/30 [==============================] - 3s 92ms/step - loss: 3.8698e-04 - mean_squared_error: 3.8698e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 28/50
# 30/30 [==============================] - 3s 93ms/step - loss: 3.4869e-04 - mean_squared_error: 3.4869e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 29/50
# 30/30 [==============================] - 2s 55ms/step - loss: 3.2897e-04 - mean_squared_error: 3.2897e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 30/50
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2277e-04 - mean_squared_error: 3.2277e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 31/50
# 30/30 [==============================] - 2s 55ms/step - loss: 3.4993e-04 - mean_squared_error: 3.4993e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 32/50
# 30/30 [==============================] - 2s 56ms/step - loss: 4.1603e-04 - mean_squared_error: 4.1603e-04 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 33/50
# 30/30 [==============================] - 2s 56ms/step - loss: 3.4713e-04 - mean_squared_error: 3.4713e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 34/50
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2297e-04 - mean_squared_error: 3.2297e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 35/50
# 30/30 [==============================] - 3s 91ms/step - loss: 3.0916e-04 - mean_squared_error: 3.0916e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 36/50
# 30/30 [==============================] - 3s 92ms/step - loss: 3.1984e-04 - mean_squared_error: 3.1984e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 37/50
# 30/30 [==============================] - 2s 72ms/step - loss: 3.3118e-04 - mean_squared_error: 3.3118e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 38/50
# 30/30 [==============================] - 2s 56ms/step - loss: 3.3038e-04 - mean_squared_error: 3.3038e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 39/50
# 30/30 [==============================] - 2s 54ms/step - loss: 2.8275e-04 - mean_squared_error: 2.8275e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 40/50
# 30/30 [==============================] - 2s 56ms/step - loss: 3.2484e-04 - mean_squared_error: 3.2484e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 41/50
# 30/30 [==============================] - 2s 56ms/step - loss: 2.9922e-04 - mean_squared_error: 2.9922e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 42/50
# 30/30 [==============================] - 2s 69ms/step - loss: 3.0676e-04 - mean_squared_error: 3.0676e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 43/50
# 30/30 [==============================] - 3s 93ms/step - loss: 2.8165e-04 - mean_squared_error: 2.8165e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 44/50
# 30/30 [==============================] - 2s 78ms/step - loss: 2.8339e-04 - mean_squared_error: 2.8339e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 45/50
# 30/30 [==============================] - 2s 56ms/step - loss: 2.8845e-04 - mean_squared_error: 2.8845e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
# Epoch 46/50
# 30/30 [==============================] - 2s 58ms/step - loss: 2.8627e-04 - mean_squared_error: 2.8627e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 47/50
# 30/30 [==============================] - 2s 57ms/step - loss: 2.8615e-04 - mean_squared_error: 2.8615e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 48/50
# 30/30 [==============================] - 2s 55ms/step - loss: 2.6128e-04 - mean_squared_error: 2.6128e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 49/50
# 30/30 [==============================] - 2s 58ms/step - loss: 2.7132e-04 - mean_squared_error: 2.7132e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
# Epoch 50/50
# 30/30 [==============================] - 3s 112ms/step - loss: 2.7310e-04 - mean_squared_error: 2.7310e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014

# %% [markdown]
# Saving best model LSTM

# %%
SAVE = True
LSTM_MODEL_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

# save the model if needed
if SAVE:
    model.save(os.path.join(LSTM_MODEL_PATH, f"best_model_{COMPANY}_LSTM.h5"))
    print("Model is saved")
# Out:
# Model is saved
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# GRU model creation

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,GRU,Dropout
from tensorflow.keras.optimizers import Adam

# define the learning rate and epochs
LR = 0.001
EPOCHS = 50

# build the model
model_GRU = Sequential()
model_GRU.add(GRU(units=50,return_sequences = True, input_shape=(train_sequences.shape[1],train_sequences.shape[2])))
model_GRU.add(Dropout(0.1))
model_GRU.add(GRU(units = 50))
model_GRU.add(Dense(4))

# compile the model
model_GRU.compile(optimizer=Adam(learning_rate = LR), loss='mean_squared_error', metrics=['mean_squared_error'])

# %% [markdown]
# Training GRU

# %%
# train the model
model_GRU.fit(train_sequences,train_labels, epochs=EPOCHS, validation_data = (test_sequences,test_labels),verbose = 'auto')
# Out:
# Epoch 1/50
# 30/30 [==============================] - 9s 154ms/step - loss: 0.0056 - mean_squared_error: 0.0056 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
# Epoch 2/50
# 30/30 [==============================] - 2s 81ms/step - loss: 7.2765e-04 - mean_squared_error: 7.2765e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 3/50
# 30/30 [==============================] - 2s 61ms/step - loss: 5.7693e-04 - mean_squared_error: 5.7693e-04 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 4/50
# 30/30 [==============================] - 2s 63ms/step - loss: 4.9481e-04 - mean_squared_error: 4.9481e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 5/50
# 30/30 [==============================] - 2s 60ms/step - loss: 4.6894e-04 - mean_squared_error: 4.6894e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 6/50
# 30/30 [==============================] - 2s 60ms/step - loss: 5.1886e-04 - mean_squared_error: 5.1886e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 7/50
# 30/30 [==============================] - 2s 60ms/step - loss: 4.7534e-04 - mean_squared_error: 4.7534e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 8/50
# 30/30 [==============================] - 3s 93ms/step - loss: 4.3520e-04 - mean_squared_error: 4.3520e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 9/50
# 30/30 [==============================] - 3s 95ms/step - loss: 4.6119e-04 - mean_squared_error: 4.6119e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 10/50
# 30/30 [==============================] - 2s 59ms/step - loss: 3.8624e-04 - mean_squared_error: 3.8624e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 11/50
# 30/30 [==============================] - 2s 58ms/step - loss: 3.9248e-04 - mean_squared_error: 3.9248e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 12/50
# 30/30 [==============================] - 2s 61ms/step - loss: 3.6136e-04 - mean_squared_error: 3.6136e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 13/50
# 30/30 [==============================] - 2s 60ms/step - loss: 3.5895e-04 - mean_squared_error: 3.5895e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 14/50
# 30/30 [==============================] - 2s 61ms/step - loss: 3.8124e-04 - mean_squared_error: 3.8124e-04 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# Epoch 15/50
# 30/30 [==============================] - 2s 74ms/step - loss: 3.5517e-04 - mean_squared_error: 3.5517e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 16/50
# 30/30 [==============================] - 3s 93ms/step - loss: 3.1724e-04 - mean_squared_error: 3.1724e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 17/50
# 30/30 [==============================] - 2s 78ms/step - loss: 3.6273e-04 - mean_squared_error: 3.6273e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 18/50
# 30/30 [==============================] - 2s 61ms/step - loss: 3.2318e-04 - mean_squared_error: 3.2318e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 19/50
# 30/30 [==============================] - 2s 62ms/step - loss: 2.9510e-04 - mean_squared_error: 2.9510e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 20/50
# 30/30 [==============================] - 2s 60ms/step - loss: 3.1146e-04 - mean_squared_error: 3.1146e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 21/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.7560e-04 - mean_squared_error: 2.7560e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 22/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.7586e-04 - mean_squared_error: 2.7586e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 23/50
# 30/30 [==============================] - 3s 94ms/step - loss: 2.8900e-04 - mean_squared_error: 2.8900e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 24/50
# 30/30 [==============================] - 3s 101ms/step - loss: 2.5696e-04 - mean_squared_error: 2.5696e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 25/50
# 30/30 [==============================] - 2s 60ms/step - loss: 2.8270e-04 - mean_squared_error: 2.8270e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 26/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.9724e-04 - mean_squared_error: 2.9724e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 27/50
# 30/30 [==============================] - 2s 62ms/step - loss: 2.4399e-04 - mean_squared_error: 2.4399e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 28/50
# 30/30 [==============================] - 2s 63ms/step - loss: 2.4432e-04 - mean_squared_error: 2.4432e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 29/50
# 30/30 [==============================] - 3s 87ms/step - loss: 2.6388e-04 - mean_squared_error: 2.6388e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 30/50
# 30/30 [==============================] - 3s 94ms/step - loss: 2.4925e-04 - mean_squared_error: 2.4925e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 31/50
# 30/30 [==============================] - 3s 91ms/step - loss: 2.6885e-04 - mean_squared_error: 2.6885e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 32/50
# 30/30 [==============================] - 2s 60ms/step - loss: 2.2916e-04 - mean_squared_error: 2.2916e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 33/50
# 30/30 [==============================] - 2s 62ms/step - loss: 2.3272e-04 - mean_squared_error: 2.3272e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 34/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.3041e-04 - mean_squared_error: 2.3041e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 35/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.4440e-04 - mean_squared_error: 2.4440e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 36/50
# 30/30 [==============================] - 2s 60ms/step - loss: 2.1219e-04 - mean_squared_error: 2.1219e-04 - val_loss: 9.6513e-04 - val_mean_squared_error: 9.6513e-04
# Epoch 37/50
# 30/30 [==============================] - 3s 86ms/step - loss: 2.2428e-04 - mean_squared_error: 2.2428e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 38/50
# 30/30 [==============================] - 3s 96ms/step - loss: 2.2011e-04 - mean_squared_error: 2.2011e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 39/50
# 30/30 [==============================] - 2s 68ms/step - loss: 2.5224e-04 - mean_squared_error: 2.5224e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 40/50
# 30/30 [==============================] - 2s 61ms/step - loss: 1.9073e-04 - mean_squared_error: 1.9073e-04 - val_loss: 9.6903e-04 - val_mean_squared_error: 9.6903e-04
# Epoch 41/50
# 30/30 [==============================] - 2s 62ms/step - loss: 1.6962e-04 - mean_squared_error: 1.6962e-04 - val_loss: 9.4081e-04 - val_mean_squared_error: 9.4081e-04
# Epoch 42/50
# 30/30 [==============================] - 2s 63ms/step - loss: 1.8834e-04 - mean_squared_error: 1.8834e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 43/50
# 30/30 [==============================] - 2s 61ms/step - loss: 2.3400e-04 - mean_squared_error: 2.3400e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 44/50
# 30/30 [==============================] - 2s 79ms/step - loss: 2.2183e-04 - mean_squared_error: 2.2183e-04 - val_loss: 9.2301e-04 - val_mean_squared_error: 9.2301e-04
# Epoch 45/50
# 30/30 [==============================] - 3s 96ms/step - loss: 2.0532e-04 - mean_squared_error: 2.0532e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 46/50
# 30/30 [==============================] - 3s 85ms/step - loss: 1.9392e-04 - mean_squared_error: 1.9392e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 47/50
# 30/30 [==============================] - 2s 63ms/step - loss: 1.8040e-04 - mean_squared_error: 1.8040e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 48/50
# 30/30 [==============================] - 2s 61ms/step - loss: 1.8693e-04 - mean_squared_error: 1.8693e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 49/50
# 30/30 [==============================] - 2s 58ms/step - loss: 1.7738e-04 - mean_squared_error: 1.7738e-04 - val_loss: 9.7093e-04 - val_mean_squared_error: 9.7093e-04
# Epoch 50/50
# 30/30 [==============================] - 2s 65ms/step - loss: 1.7405e-04 - mean_squared_error: 1.7405e-04 - val_loss: 8.6232e-04 - val_mean_squared_error: 8.6232e-04

# %% [markdown]
# Saving best GRU model

# %%
SAVE = True
GRU_MODEL_PATH = "/content/drive/Shareddrives/1:1_Krishna_Vijay/Results/Models/"

# save the model if needed
if SAVE:
    model_GRU.save(os.path.join(GRU_MODEL_PATH, f"best_model_{COMPANY}_GRU.h5"))
    print("Model is saved")
# Out:
# Model is saved
